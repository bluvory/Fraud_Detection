# %% [markdown]
# ## libraries

# %%
import pandas as pd
import math
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.model_selection import train_test_split

# sampling
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from imblearn.pipeline import make_pipeline as imbalanced_make_pipeline

# Classifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
import xgboost
import lightgbm
import catboost

# Bagging
from sklearn.ensemble import BaggingClassifier

# Forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import IsolationForest

# DBSCAN
from sklearn.cluster import DBSCAN

# %% [markdown]
# ## Data

# %%
df = pd.read_csv('../creditcard.csv')

std_scaler = StandardScaler()
rob_scaler = RobustScaler()

df['scaled_amount'] = rob_scaler.fit_transform(df['Amount'].values.reshape(-1,1))
df['scaled_time'] = rob_scaler.fit_transform(df['Time'].values.reshape(-1,1))

df.drop(['Time','Amount'], axis=1, inplace=True)

scaled_amount = df['scaled_amount']
scaled_time = df['scaled_time']

df.drop(['scaled_amount', 'scaled_time'], axis=1, inplace=True)
df.insert(0, 'scaled_amount', scaled_amount)
df.insert(1, 'scaled_time', scaled_time)

df = df.sample(frac=1)  #shuffle


# undersampling
fraud_df = df.loc[df['Class'] == 1]
non_fraud_df = df.loc[df['Class'] == 0][:492]
normal_distributed_df = pd.concat([fraud_df, non_fraud_df])
df_un = normal_distributed_df.sample(frac=1, random_state=42)

# oversampling with SMOTE
sm = SMOTE(sampling_strategy='minority')
X_sm, y_sm = sm.fit_resample(df.drop('Class', axis=1), df['Class'])

# %%
X_sm.shape, y_sm.shape
# Out:
# ((568630, 30), (568630,))

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class', axis=1), df['Class'], test_size=0.3, random_state=42)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((199364, 30), (199364,), (85443, 30), (85443,))

# %%
X_train_un, X_test_un, y_train_un, y_test_un = train_test_split(df_un.drop('Class', axis=1), df_un['Class'], test_size=0.3, random_state=42)
X_train_un.shape, y_train_un.shape, X_test_un.shape, y_test_un.shape
# Out:
# ((688, 30), (688,), (296, 30), (296,))

# %%
X_train_ov, X_test_ov, y_train_ov, y_test_ov = train_test_split(X_sm, y_sm, test_size=0.3, random_state=42)
X_train_ov.shape, y_train_ov.shape, X_test_ov.shape, y_test_ov.shape
# Out:
# ((398041, 30), (398041,), (170589, 30), (170589,))

# %% [markdown]
# # Classifier

# %%
classifiers = {
    "LogisiticRegression": LogisticRegression(),
    "KNearest": KNeighborsClassifier(),
    "Support Vector Classifier": SVC(),
    "DecisionTreeClassifier": DecisionTreeClassifier()
}

for key, classifier in classifiers.items():
    classifier.fit(X_train, y_train)
    training_score = cross_val_score(classifier, X_train, y_train, cv=5)
    print(classifier.__class__.__name__, "training score:", training_score.mean())

# %%
classifiers = {
    "LogisiticRegression": LogisticRegression(),
    "KNearest": KNeighborsClassifier(),
    "Support Vector Classifier": SVC(),
    "DecisionTreeClassifier": DecisionTreeClassifier()
}

for key, classifier in classifiers.items():
    classifier.fit(X_train_un, y_train_un)
    training_score = cross_val_score(classifier, X_train_un, y_train_un, cv=5)
    print(classifier.__class__.__name__, "undersampling training score:", training_score.mean())

# %%
classifiers = {
    "LogisiticRegression": LogisticRegression(),
    "KNearest": KNeighborsClassifier(),
    "Support Vector Classifier": SVC(),
    "DecisionTreeClassifier": DecisionTreeClassifier()
}

for key, classifier in classifiers.items():
    classifier.fit(X_train_ov, y_train_ov)
    training_score = cross_val_score(classifier, X_train_ov, y_train_ov, cv=5)
    print(classifier.__class__.__name__, "oversampling training score:", training_score.mean())

# %% [markdown]
# # Boosting
# 여러개의 학습모형을 연결하여 앞의 모형을 보완해 가면서 뒤로 갈수록 더욱 강한 모형을 만듬

# %% [markdown]
# ## AdaBoost
# - 이전 모형을 보완하여 새로운 모형을 만드는 방법의 기본은 이전 모형이 잘 맞추지 못한 데이터에 대해 가중치를 더 높임
# - 새로운 모형은 가중치가 더 높은 데이터를 잘 구분하려고 하므로 어려운 데이터를 점점 더 잘 분류할 수 있게 됨
# - 단점: Bagging이나 Pating처럼 병렬화가 안됨

# %%
ada_clf = AdaBoostClassifier( 
    DecisionTreeClassifier(max_depth=1), 
    n_estimators=200, 
    algorithm="SAMME.R", 
    learning_rate=0.5 
)
ada_clf.fit(X_train, y_train) 

y_pred = ada_clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9993562960102056

# %%
ada_clf = AdaBoostClassifier()
ada_clf.fit(X_train, y_train) 

y_pred = ada_clf.predict(X_test)
print('accuracy:', accuracy_score(y_test, y_pred))

# %%
ada_clf_un = AdaBoostClassifier()
ada_clf_un.fit(X_train_un, y_train_un) 

y_pred_un = ada_clf.predict(X_test_un)
print('undersampling accuracy:', accuracy_score(y_test_un, y_pred_un))

# %%
ada_clf_ov = AdaBoostClassifier()
ada_clf_ov.fit(X_train_ov, y_train_ov) 

y_pred_ov = ada_clf.predict(X_test_ov)
print('undersampling accuracy:', accuracy_score(y_test_ov, y_pred_ov))

# %% [markdown]
# ## Gradient Boost
# 이전 모형이 만든 잔여 오차에 대한 새로운 모형을 학습시킴

# %%
gb_clf = GradientBoostingClassifier()
gb_clf.fit(X_train, y_train)

y_pred = gb_clf.predict(X_test)
print('accuracy:', accuracy_score(y_test, y_pred))
# Out:
# 0.9988179254005595

# %%
ada_clf_un = AdaBoostClassifier()
ada_clf_un.fit(X_train_un, y_train_un) 

y_pred_un = ada_clf.predict(X_test_un)
print('undersampling accuracy:', accuracy_score(y_test_un, y_pred_un))

# %%
ada_clf_ov = AdaBoostClassifier()
ada_clf_ov.fit(X_train_ov, y_train_ov) 

y_pred_ov = ada_clf.predict(X_test_ov)
print('oversampling accuracy:', accuracy_score(y_test_ov, y_pred_ov))

# %% [markdown]
# ## 확률적 그래디언트 부스트 (Stochastic Gradient Boost)
# - 그래디언트 부스트 방안이 트리를 학습할때 사용할 학습 데이터의 비율 지정
# - 데이터를 무작위로 뽑아서 학습

# %% [markdown]
# ## XGBOOST

# %%
xgb_clf = xgboost.XGBClassifier(max_depth=2, eta=1)
xgb_clf.fit(X_train, y_train)

y_pred = xgb_clf.predict(X_test)
print('accuracy:', accuracy_score(y_test, y_pred))
# Out:
# /home/jovyan/.local/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:16:34] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9994850368081645

# %%
xgb_clf = xgboost.XGBClassifier(max_depth=2, eta=1)
xgb_clf.fit(X_train, y_train)

y_pred = xgb_clf.predict(X_test)
print('undersampling accuracy:', accuracy_score(y_test_un, y_pred_un))

# %%
xgb_clf = xgboost.XGBClassifier(max_depth=2, eta=1)
xgb_clf.fit(X_train, y_train)

y_pred = xgb_clf.predict(X_test)
print('oversampling accuracy:', accuracy_score(y_test_ov, y_pred_ov))

# %% [markdown]
# ## lightGBM

# %%
lgb_clf = lightgbm.LGBMClassifier()
lgb_clf.fit(X_train, y_train)

y_pred = lgb_clf.predict(X_test)
print('accuracy:', accuracy_score(y_test, y_pred))

# %%
lgb_clf = lightgbm.LGBMClassifier()
lgb_clf.fit(X_train, y_train)

y_pred = lgb_clf.predict(X_test)
print('undersampling accuracy:', accuracy_score(y_test_un, y_pred_un))
# Out:
# 0.996477183619489

# %%
lgb_clf = lightgbm.LGBMClassifier()
lgb_clf.fit(X_train, y_train)

y_pred = lgb_clf.predict(X_test)
print('oversampling accuracy:', accuracy_score(y_test_ov, y_pred_ov))

# %% [markdown]
# ## CATBOOST

# %%
cat_clf = catboost.CatBoostClassifier()
cat_clf.fit(X_train, y_train)

y_pred = cat_clf.predict(X_test)
print('accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Learning rate set to 0.098829
# 0:	learn: 0.3769827	total: 72.6ms	remaining: 1m 12s
# 1:	learn: 0.2031768	total: 91.1ms	remaining: 45.5s
# 2:	learn: 0.1124142	total: 110ms	remaining: 36.6s
# 3:	learn: 0.0641434	total: 128ms	remaining: 31.9s
# 4:	learn: 0.0387952	total: 146ms	remaining: 29s
# 5:	learn: 0.0243379	total: 163ms	remaining: 27s
# 6:	learn: 0.0165542	total: 180ms	remaining: 25.6s
# 7:	learn: 0.0118911	total: 198ms	remaining: 24.5s
# 8:	learn: 0.0091057	total: 214ms	remaining: 23.6s
# 9:	learn: 0.0072142	total: 231ms	remaining: 22.8s
# 10:	learn: 0.0059931	total: 246ms	remaining: 22.1s
# 11:	learn: 0.0051635	total: 262ms	remaining: 21.6s
# 12:	learn: 0.0045369	total: 277ms	remaining: 21.1s
# 13:	learn: 0.0040811	total: 292ms	remaining: 20.6s
# 14:	learn: 0.0038058	total: 309ms	remaining: 20.3s
# 15:	learn: 0.0035599	total: 324ms	remaining: 19.9s
# 16:	learn: 0.0033912	total: 339ms	remaining: 19.6s
# 17:	learn: 0.0032564	total: 356ms	remaining: 19.4s
# 18:	learn: 0.0031452	total: 371ms	remaining: 19.2s
# 19:	learn: 0.0030752	total: 385ms	remaining: 18.9s
# 20:	learn: 0.0030059	total: 400ms	remaining: 18.6s
# 21:	learn: 0.0029640	total: 414ms	remaining: 18.4s
# 22:	learn: 0.0029188	total: 429ms	remaining: 18.2s
# 23:	learn: 0.0028692	total: 445ms	remaining: 18.1s
# 24:	learn: 0.0027964	total: 459ms	remaining: 17.9s
# 25:	learn: 0.0027352	total: 476ms	remaining: 17.8s
# 26:	learn: 0.0026777	total: 493ms	remaining: 17.8s
# 27:	learn: 0.0026304	total: 512ms	remaining: 17.8s
# 28:	learn: 0.0025831	total: 528ms	remaining: 17.7s
# 29:	learn: 0.0025231	total: 546ms	remaining: 17.6s
# 30:	learn: 0.0024873	total: 562ms	remaining: 17.6s
# 31:	learn: 0.0024603	total: 578ms	remaining: 17.5s
# 32:	learn: 0.0024178	total: 594ms	remaining: 17.4s
# 33:	learn: 0.0024103	total: 610ms	remaining: 17.3s
# 34:	learn: 0.0024029	total: 626ms	remaining: 17.3s
# 35:	learn: 0.0023940	total: 642ms	remaining: 17.2s
# 36:	learn: 0.0023826	total: 657ms	remaining: 17.1s
# 37:	learn: 0.0023669	total: 674ms	remaining: 17.1s
# 38:	learn: 0.0023485	total: 691ms	remaining: 17s
# 39:	learn: 0.0023409	total: 705ms	remaining: 16.9s
# 40:	learn: 0.0023132	total: 721ms	remaining: 16.9s
# 41:	learn: 0.0022939	total: 736ms	remaining: 16.8s
# 42:	learn: 0.0022816	total: 751ms	remaining: 16.7s
# 43:	learn: 0.0022736	total: 765ms	remaining: 16.6s
# 44:	learn: 0.0022507	total: 780ms	remaining: 16.6s
# 45:	learn: 0.0022455	total: 795ms	remaining: 16.5s
# 46:	learn: 0.0022172	total: 810ms	remaining: 16.4s
# 47:	learn: 0.0022006	total: 825ms	remaining: 16.4s
# 48:	learn: 0.0021801	total: 840ms	remaining: 16.3s
# 49:	learn: 0.0021636	total: 855ms	remaining: 16.3s
# 50:	learn: 0.0021561	total: 870ms	remaining: 16.2s
# 51:	learn: 0.0021455	total: 886ms	remaining: 16.1s
# 52:	learn: 0.0021387	total: 901ms	remaining: 16.1s
# 53:	learn: 0.0021310	total: 918ms	remaining: 16.1s
# 54:	learn: 0.0021229	total: 933ms	remaining: 16s
# 55:	learn: 0.0021140	total: 951ms	remaining: 16s
# 56:	learn: 0.0021028	total: 970ms	remaining: 16s
# 57:	learn: 0.0020904	total: 990ms	remaining: 16.1s
# 58:	learn: 0.0020790	total: 1.01s	remaining: 16.1s
# 59:	learn: 0.0020707	total: 1.03s	remaining: 16.1s
# 60:	learn: 0.0020641	total: 1.05s	remaining: 16.1s
# 61:	learn: 0.0020559	total: 1.07s	remaining: 16.1s
# 62:	learn: 0.0020355	total: 1.08s	remaining: 16.1s
# 63:	learn: 0.0020189	total: 1.1s	remaining: 16s
# 64:	learn: 0.0020052	total: 1.11s	remaining: 16s
# 65:	learn: 0.0019881	total: 1.13s	remaining: 15.9s
# 66:	learn: 0.0019811	total: 1.14s	remaining: 15.9s
# 67:	learn: 0.0019723	total: 1.16s	remaining: 15.9s
# 68:	learn: 0.0019617	total: 1.17s	remaining: 15.8s
# 69:	learn: 0.0019554	total: 1.19s	remaining: 15.8s
# 70:	learn: 0.0019512	total: 1.2s	remaining: 15.7s
# 71:	learn: 0.0019455	total: 1.22s	remaining: 15.7s
# 72:	learn: 0.0019344	total: 1.23s	remaining: 15.6s
# 73:	learn: 0.0019221	total: 1.25s	remaining: 15.6s
# 74:	learn: 0.0019192	total: 1.26s	remaining: 15.5s
# 75:	learn: 0.0019137	total: 1.27s	remaining: 15.5s
# 76:	learn: 0.0019089	total: 1.29s	remaining: 15.5s
# 77:	learn: 0.0019038	total: 1.3s	remaining: 15.4s
# 78:	learn: 0.0018830	total: 1.32s	remaining: 15.4s
# 79:	learn: 0.0018771	total: 1.33s	remaining: 15.3s
# 80:	learn: 0.0018688	total: 1.35s	remaining: 15.3s
# 81:	learn: 0.0018585	total: 1.36s	remaining: 15.3s
# 82:	learn: 0.0018520	total: 1.38s	remaining: 15.2s
# 83:	learn: 0.0018445	total: 1.39s	remaining: 15.2s
# 84:	learn: 0.0018371	total: 1.41s	remaining: 15.2s
# 85:	learn: 0.0018289	total: 1.42s	remaining: 15.1s
# 86:	learn: 0.0018127	total: 1.44s	remaining: 15.1s
# 87:	learn: 0.0018014	total: 1.45s	remaining: 15.1s
# 88:	learn: 0.0017920	total: 1.47s	remaining: 15s
# 89:	learn: 0.0017847	total: 1.48s	remaining: 15s
# 90:	learn: 0.0017725	total: 1.5s	remaining: 15s
# 91:	learn: 0.0017684	total: 1.51s	remaining: 14.9s
# 92:	learn: 0.0017501	total: 1.53s	remaining: 14.9s
# 93:	learn: 0.0017452	total: 1.54s	remaining: 14.9s
# 94:	learn: 0.0017341	total: 1.56s	remaining: 14.9s
# 95:	learn: 0.0017135	total: 1.58s	remaining: 14.9s
# 96:	learn: 0.0017027	total: 1.59s	remaining: 14.8s
# 97:	learn: 0.0017000	total: 1.61s	remaining: 14.8s
# 98:	learn: 0.0016874	total: 1.63s	remaining: 14.8s
# 99:	learn: 0.0016821	total: 1.64s	remaining: 14.8s
# 100:	learn: 0.0016770	total: 1.66s	remaining: 14.7s
# 101:	learn: 0.0016721	total: 1.67s	remaining: 14.7s
# 102:	learn: 0.0016639	total: 1.69s	remaining: 14.7s
# 103:	learn: 0.0016567	total: 1.7s	remaining: 14.7s
# 104:	learn: 0.0016482	total: 1.72s	remaining: 14.7s
# 105:	learn: 0.0016379	total: 1.73s	remaining: 14.6s
# 106:	learn: 0.0016339	total: 1.75s	remaining: 14.6s
# 107:	learn: 0.0016265	total: 1.76s	remaining: 14.6s
# 108:	learn: 0.0016209	total: 1.78s	remaining: 14.5s
# 109:	learn: 0.0016110	total: 1.79s	remaining: 14.5s
# 110:	learn: 0.0016042	total: 1.81s	remaining: 14.5s
# 111:	learn: 0.0015930	total: 1.82s	remaining: 14.5s
# 112:	learn: 0.0015675	total: 1.84s	remaining: 14.4s
# 113:	learn: 0.0015642	total: 1.85s	remaining: 14.4s
# 114:	learn: 0.0015570	total: 1.87s	remaining: 14.4s
# 115:	learn: 0.0015503	total: 1.89s	remaining: 14.4s
# 116:	learn: 0.0015421	total: 1.9s	remaining: 14.4s
# 117:	learn: 0.0015390	total: 1.92s	remaining: 14.3s
# 118:	learn: 0.0015270	total: 1.93s	remaining: 14.3s
# 119:	learn: 0.0015210	total: 1.95s	remaining: 14.3s
# 120:	learn: 0.0015166	total: 1.96s	remaining: 14.3s
# 121:	learn: 0.0015088	total: 1.98s	remaining: 14.2s
# 122:	learn: 0.0015019	total: 1.99s	remaining: 14.2s
# 123:	learn: 0.0014972	total: 2.01s	remaining: 14.2s
# 124:	learn: 0.0014904	total: 2.02s	remaining: 14.2s
# 125:	learn: 0.0014760	total: 2.04s	remaining: 14.1s
# 126:	learn: 0.0014615	total: 2.05s	remaining: 14.1s
# 127:	learn: 0.0014576	total: 2.07s	remaining: 14.1s
# 128:	learn: 0.0014509	total: 2.08s	remaining: 14.1s
# 129:	learn: 0.0014482	total: 2.1s	remaining: 14.1s
# 130:	learn: 0.0014443	total: 2.12s	remaining: 14s
# 131:	learn: 0.0014388	total: 2.13s	remaining: 14s
# 132:	learn: 0.0014227	total: 2.15s	remaining: 14s
# 133:	learn: 0.0014155	total: 2.16s	remaining: 14s
# 134:	learn: 0.0014064	total: 2.18s	remaining: 14s
# 135:	learn: 0.0013990	total: 2.19s	remaining: 13.9s
# 136:	learn: 0.0013809	total: 2.21s	remaining: 13.9s
# 137:	learn: 0.0013781	total: 2.23s	remaining: 13.9s
# 138:	learn: 0.0013615	total: 2.24s	remaining: 13.9s
# 139:	learn: 0.0013518	total: 2.26s	remaining: 13.9s
# 140:	learn: 0.0013453	total: 2.27s	remaining: 13.8s
# 141:	learn: 0.0013314	total: 2.29s	remaining: 13.8s
# 142:	learn: 0.0013282	total: 2.3s	remaining: 13.8s
# 143:	learn: 0.0013202	total: 2.32s	remaining: 13.8s
# 144:	learn: 0.0013159	total: 2.33s	remaining: 13.8s
# 145:	learn: 0.0013104	total: 2.35s	remaining: 13.7s
# 146:	learn: 0.0013082	total: 2.36s	remaining: 13.7s
# 147:	learn: 0.0012975	total: 2.38s	remaining: 13.7s
# 148:	learn: 0.0012899	total: 2.39s	remaining: 13.7s
# 149:	learn: 0.0012846	total: 2.41s	remaining: 13.6s
# 150:	learn: 0.0012802	total: 2.42s	remaining: 13.6s
# 151:	learn: 0.0012773	total: 2.44s	remaining: 13.6s
# 152:	learn: 0.0012744	total: 2.45s	remaining: 13.6s
# 153:	learn: 0.0012682	total: 2.47s	remaining: 13.5s
# 154:	learn: 0.0012664	total: 2.48s	remaining: 13.5s
# 155:	learn: 0.0012629	total: 2.49s	remaining: 13.5s
# 156:	learn: 0.0012589	total: 2.51s	remaining: 13.5s
# 157:	learn: 0.0012568	total: 2.52s	remaining: 13.5s
# 158:	learn: 0.0012557	total: 2.54s	remaining: 13.4s
# 159:	learn: 0.0012530	total: 2.56s	remaining: 13.4s
# 160:	learn: 0.0012469	total: 2.57s	remaining: 13.4s
# 161:	learn: 0.0012353	total: 2.58s	remaining: 13.4s
# 162:	learn: 0.0012337	total: 2.6s	remaining: 13.4s
# 163:	learn: 0.0012288	total: 2.62s	remaining: 13.3s
# 164:	learn: 0.0012177	total: 2.63s	remaining: 13.3s
# 165:	learn: 0.0012137	total: 2.65s	remaining: 13.3s
# 166:	learn: 0.0012083	total: 2.66s	remaining: 13.3s
# 167:	learn: 0.0012061	total: 2.68s	remaining: 13.3s
# 168:	learn: 0.0012011	total: 2.69s	remaining: 13.2s
# 169:	learn: 0.0011997	total: 2.71s	remaining: 13.2s
# 170:	learn: 0.0011936	total: 2.72s	remaining: 13.2s
# 171:	learn: 0.0011892	total: 2.74s	remaining: 13.2s
# 172:	learn: 0.0011853	total: 2.75s	remaining: 13.2s
# 173:	learn: 0.0011817	total: 2.77s	remaining: 13.1s
# 174:	learn: 0.0011764	total: 2.78s	remaining: 13.1s
# 175:	learn: 0.0011752	total: 2.8s	remaining: 13.1s
# 176:	learn: 0.0011700	total: 2.81s	remaining: 13.1s
# 177:	learn: 0.0011589	total: 2.83s	remaining: 13.1s
# 178:	learn: 0.0011570	total: 2.84s	remaining: 13s
# 179:	learn: 0.0011535	total: 2.86s	remaining: 13s
# 180:	learn: 0.0011514	total: 2.87s	remaining: 13s
# 181:	learn: 0.0011394	total: 2.89s	remaining: 13s
# 182:	learn: 0.0011303	total: 2.9s	remaining: 13s
# 183:	learn: 0.0011282	total: 2.92s	remaining: 12.9s
# 184:	learn: 0.0011241	total: 2.93s	remaining: 12.9s
# 185:	learn: 0.0011162	total: 2.95s	remaining: 12.9s
# 186:	learn: 0.0011134	total: 2.96s	remaining: 12.9s
# 187:	learn: 0.0011094	total: 2.98s	remaining: 12.9s
# 188:	learn: 0.0011071	total: 2.99s	remaining: 12.8s
# 189:	learn: 0.0010962	total: 3.01s	remaining: 12.8s
# 190:	learn: 0.0010933	total: 3.02s	remaining: 12.8s
# 191:	learn: 0.0010840	total: 3.04s	remaining: 12.8s
# 192:	learn: 0.0010806	total: 3.05s	remaining: 12.8s
# 193:	learn: 0.0010774	total: 3.07s	remaining: 12.8s
# 194:	learn: 0.0010745	total: 3.08s	remaining: 12.7s
# 195:	learn: 0.0010718	total: 3.1s	remaining: 12.7s
# 196:	learn: 0.0010699	total: 3.12s	remaining: 12.7s
# 197:	learn: 0.0010672	total: 3.13s	remaining: 12.7s
# 198:	learn: 0.0010645	total: 3.14s	remaining: 12.7s
# 199:	learn: 0.0010629	total: 3.16s	remaining: 12.6s
# 200:	learn: 0.0010574	total: 3.17s	remaining: 12.6s
# 201:	learn: 0.0010561	total: 3.19s	remaining: 12.6s
# 202:	learn: 0.0010504	total: 3.21s	remaining: 12.6s
# 203:	learn: 0.0010465	total: 3.22s	remaining: 12.6s
# 204:	learn: 0.0010446	total: 3.23s	remaining: 12.5s
# 205:	learn: 0.0010428	total: 3.25s	remaining: 12.5s
# 206:	learn: 0.0010403	total: 3.26s	remaining: 12.5s
# 207:	learn: 0.0010315	total: 3.28s	remaining: 12.5s
# 208:	learn: 0.0010300	total: 3.29s	remaining: 12.5s
# 209:	learn: 0.0010284	total: 3.31s	remaining: 12.4s
# 210:	learn: 0.0010262	total: 3.33s	remaining: 12.4s
# 211:	learn: 0.0010232	total: 3.34s	remaining: 12.4s
# 212:	learn: 0.0010157	total: 3.36s	remaining: 12.4s
# 213:	learn: 0.0010144	total: 3.38s	remaining: 12.4s
# 214:	learn: 0.0010120	total: 3.39s	remaining: 12.4s
# 215:	learn: 0.0010077	total: 3.4s	remaining: 12.4s
# 216:	learn: 0.0010030	total: 3.42s	remaining: 12.3s
# 217:	learn: 0.0009977	total: 3.44s	remaining: 12.3s
# 218:	learn: 0.0009928	total: 3.45s	remaining: 12.3s
# 219:	learn: 0.0009909	total: 3.47s	remaining: 12.3s
# 220:	learn: 0.0009888	total: 3.48s	remaining: 12.3s
# 221:	learn: 0.0009815	total: 3.5s	remaining: 12.3s
# 222:	learn: 0.0009761	total: 3.52s	remaining: 12.3s
# 223:	learn: 0.0009734	total: 3.53s	remaining: 12.2s
# 224:	learn: 0.0009713	total: 3.55s	remaining: 12.2s
# 225:	learn: 0.0009678	total: 3.56s	remaining: 12.2s
# 226:	learn: 0.0009654	total: 3.58s	remaining: 12.2s
# 227:	learn: 0.0009614	total: 3.59s	remaining: 12.2s
# 228:	learn: 0.0009582	total: 3.61s	remaining: 12.1s
# 229:	learn: 0.0009561	total: 3.62s	remaining: 12.1s
# 230:	learn: 0.0009518	total: 3.64s	remaining: 12.1s
# 231:	learn: 0.0009504	total: 3.65s	remaining: 12.1s
# 232:	learn: 0.0009469	total: 3.67s	remaining: 12.1s
# 233:	learn: 0.0009423	total: 3.68s	remaining: 12s
# 234:	learn: 0.0009406	total: 3.69s	remaining: 12s
# 235:	learn: 0.0009336	total: 3.71s	remaining: 12s
# 236:	learn: 0.0009319	total: 3.73s	remaining: 12s
# 237:	learn: 0.0009283	total: 3.74s	remaining: 12s
# 238:	learn: 0.0009272	total: 3.76s	remaining: 12s
# 239:	learn: 0.0009262	total: 3.77s	remaining: 11.9s
# 240:	learn: 0.0009238	total: 3.79s	remaining: 11.9s
# 241:	learn: 0.0009220	total: 3.8s	remaining: 11.9s
# 242:	learn: 0.0009208	total: 3.82s	remaining: 11.9s
# 243:	learn: 0.0009185	total: 3.83s	remaining: 11.9s
# 244:	learn: 0.0009170	total: 3.85s	remaining: 11.9s
# 245:	learn: 0.0009152	total: 3.86s	remaining: 11.8s
# 246:	learn: 0.0009139	total: 3.88s	remaining: 11.8s
# 247:	learn: 0.0009122	total: 3.89s	remaining: 11.8s
# 248:	learn: 0.0009107	total: 3.91s	remaining: 11.8s
# 249:	learn: 0.0009079	total: 3.92s	remaining: 11.8s
# 250:	learn: 0.0009011	total: 3.94s	remaining: 11.7s
# 251:	learn: 0.0008953	total: 3.95s	remaining: 11.7s
# 252:	learn: 0.0008911	total: 3.97s	remaining: 11.7s
# 253:	learn: 0.0008891	total: 3.98s	remaining: 11.7s
# 254:	learn: 0.0008883	total: 3.99s	remaining: 11.7s
# 255:	learn: 0.0008873	total: 4.01s	remaining: 11.7s
# 256:	learn: 0.0008803	total: 4.02s	remaining: 11.6s
# 257:	learn: 0.0008787	total: 4.04s	remaining: 11.6s
# 258:	learn: 0.0008757	total: 4.05s	remaining: 11.6s
# 259:	learn: 0.0008733	total: 4.07s	remaining: 11.6s
# 260:	learn: 0.0008724	total: 4.08s	remaining: 11.6s
# 261:	learn: 0.0008698	total: 4.1s	remaining: 11.5s
# 262:	learn: 0.0008664	total: 4.11s	remaining: 11.5s
# 263:	learn: 0.0008649	total: 4.13s	remaining: 11.5s
# 264:	learn: 0.0008630	total: 4.14s	remaining: 11.5s
# 265:	learn: 0.0008622	total: 4.16s	remaining: 11.5s
# 266:	learn: 0.0008595	total: 4.17s	remaining: 11.5s
# 267:	learn: 0.0008591	total: 4.19s	remaining: 11.4s
# 268:	learn: 0.0008560	total: 4.2s	remaining: 11.4s
# 269:	learn: 0.0008533	total: 4.22s	remaining: 11.4s
# 270:	learn: 0.0008519	total: 4.23s	remaining: 11.4s
# 271:	learn: 0.0008507	total: 4.25s	remaining: 11.4s
# 272:	learn: 0.0008485	total: 4.26s	remaining: 11.3s
# 273:	learn: 0.0008468	total: 4.28s	remaining: 11.3s
# 274:	learn: 0.0008446	total: 4.29s	remaining: 11.3s
# 275:	learn: 0.0008438	total: 4.3s	remaining: 11.3s
# 276:	learn: 0.0008399	total: 4.32s	remaining: 11.3s
# 277:	learn: 0.0008382	total: 4.33s	remaining: 11.3s
# 278:	learn: 0.0008302	total: 4.35s	remaining: 11.2s
# 279:	learn: 0.0008296	total: 4.36s	remaining: 11.2s
# 280:	learn: 0.0008274	total: 4.38s	remaining: 11.2s
# 281:	learn: 0.0008258	total: 4.39s	remaining: 11.2s
# 282:	learn: 0.0008246	total: 4.41s	remaining: 11.2s
# 283:	learn: 0.0008227	total: 4.42s	remaining: 11.2s
# 284:	learn: 0.0008199	total: 4.44s	remaining: 11.1s
# 285:	learn: 0.0008189	total: 4.46s	remaining: 11.1s
# 286:	learn: 0.0008176	total: 4.47s	remaining: 11.1s
# 287:	learn: 0.0008143	total: 4.49s	remaining: 11.1s
# 288:	learn: 0.0008129	total: 4.5s	remaining: 11.1s
# 289:	learn: 0.0008114	total: 4.52s	remaining: 11.1s
# 290:	learn: 0.0008082	total: 4.53s	remaining: 11s
# 291:	learn: 0.0008044	total: 4.55s	remaining: 11s
# 292:	learn: 0.0007963	total: 4.57s	remaining: 11s
# 293:	learn: 0.0007909	total: 4.58s	remaining: 11s
# 294:	learn: 0.0007896	total: 4.6s	remaining: 11s
# 295:	learn: 0.0007882	total: 4.62s	remaining: 11s
# 296:	learn: 0.0007862	total: 4.63s	remaining: 11s
# 297:	learn: 0.0007850	total: 4.65s	remaining: 11s
# 298:	learn: 0.0007836	total: 4.67s	remaining: 10.9s
# 299:	learn: 0.0007800	total: 4.69s	remaining: 10.9s
# 300:	learn: 0.0007787	total: 4.7s	remaining: 10.9s
# 301:	learn: 0.0007758	total: 4.72s	remaining: 10.9s
# 302:	learn: 0.0007745	total: 4.73s	remaining: 10.9s
# 303:	learn: 0.0007737	total: 4.74s	remaining: 10.9s
# 304:	learn: 0.0007708	total: 4.76s	remaining: 10.8s
# 305:	learn: 0.0007697	total: 4.77s	remaining: 10.8s
# 306:	learn: 0.0007651	total: 4.79s	remaining: 10.8s
# 307:	learn: 0.0007522	total: 4.8s	remaining: 10.8s
# 308:	learn: 0.0007510	total: 4.82s	remaining: 10.8s
# 309:	learn: 0.0007482	total: 4.83s	remaining: 10.8s
# 310:	learn: 0.0007467	total: 4.85s	remaining: 10.7s
# 311:	learn: 0.0007452	total: 4.86s	remaining: 10.7s
# 312:	learn: 0.0007442	total: 4.88s	remaining: 10.7s
# 313:	learn: 0.0007431	total: 4.89s	remaining: 10.7s
# 314:	learn: 0.0007408	total: 4.91s	remaining: 10.7s
# 315:	learn: 0.0007383	total: 4.92s	remaining: 10.7s
# 316:	learn: 0.0007377	total: 4.94s	remaining: 10.6s
# 317:	learn: 0.0007360	total: 4.95s	remaining: 10.6s
# 318:	learn: 0.0007306	total: 4.97s	remaining: 10.6s
# 319:	learn: 0.0007293	total: 4.98s	remaining: 10.6s
# 320:	learn: 0.0007287	total: 5s	remaining: 10.6s
# 321:	learn: 0.0007267	total: 5.01s	remaining: 10.6s
# 322:	learn: 0.0007257	total: 5.03s	remaining: 10.5s
# 323:	learn: 0.0007245	total: 5.04s	remaining: 10.5s
# 324:	learn: 0.0007216	total: 5.06s	remaining: 10.5s
# 325:	learn: 0.0007183	total: 5.07s	remaining: 10.5s
# 326:	learn: 0.0007154	total: 5.09s	remaining: 10.5s
# 327:	learn: 0.0007123	total: 5.11s	remaining: 10.5s
# 328:	learn: 0.0007104	total: 5.12s	remaining: 10.4s
# 329:	learn: 0.0007073	total: 5.13s	remaining: 10.4s
# 330:	learn: 0.0007067	total: 5.15s	remaining: 10.4s
# 331:	learn: 0.0007047	total: 5.16s	remaining: 10.4s
# 332:	learn: 0.0007017	total: 5.18s	remaining: 10.4s
# 333:	learn: 0.0007010	total: 5.2s	remaining: 10.4s
# 334:	learn: 0.0007002	total: 5.21s	remaining: 10.3s
# 335:	learn: 0.0006976	total: 5.22s	remaining: 10.3s
# 336:	learn: 0.0006965	total: 5.24s	remaining: 10.3s
# 337:	learn: 0.0006939	total: 5.25s	remaining: 10.3s
# 338:	learn: 0.0006929	total: 5.27s	remaining: 10.3s
# 339:	learn: 0.0006878	total: 5.29s	remaining: 10.3s
# 340:	learn: 0.0006871	total: 5.3s	remaining: 10.2s
# 341:	learn: 0.0006858	total: 5.32s	remaining: 10.2s
# 342:	learn: 0.0006834	total: 5.33s	remaining: 10.2s
# 343:	learn: 0.0006813	total: 5.34s	remaining: 10.2s
# 344:	learn: 0.0006805	total: 5.36s	remaining: 10.2s
# 345:	learn: 0.0006741	total: 5.38s	remaining: 10.2s
# 346:	learn: 0.0006731	total: 5.39s	remaining: 10.1s
# 347:	learn: 0.0006716	total: 5.41s	remaining: 10.1s
# 348:	learn: 0.0006696	total: 5.42s	remaining: 10.1s
# 349:	learn: 0.0006686	total: 5.44s	remaining: 10.1s
# 350:	learn: 0.0006661	total: 5.45s	remaining: 10.1s
# 351:	learn: 0.0006626	total: 5.47s	remaining: 10.1s
# 352:	learn: 0.0006613	total: 5.48s	remaining: 10s
# 353:	learn: 0.0006599	total: 5.5s	remaining: 10s
# 354:	learn: 0.0006576	total: 5.51s	remaining: 10s
# 355:	learn: 0.0006559	total: 5.53s	remaining: 10s
# 356:	learn: 0.0006549	total: 5.54s	remaining: 9.98s
# 357:	learn: 0.0006515	total: 5.56s	remaining: 9.97s
# 358:	learn: 0.0006506	total: 5.57s	remaining: 9.95s
# 359:	learn: 0.0006483	total: 5.59s	remaining: 9.93s
# 360:	learn: 0.0006450	total: 5.6s	remaining: 9.92s
# 361:	learn: 0.0006419	total: 5.62s	remaining: 9.9s
# 362:	learn: 0.0006403	total: 5.63s	remaining: 9.88s
# 363:	learn: 0.0006373	total: 5.65s	remaining: 9.87s
# 364:	learn: 0.0006360	total: 5.66s	remaining: 9.85s
# 365:	learn: 0.0006271	total: 5.68s	remaining: 9.84s
# 366:	learn: 0.0006257	total: 5.69s	remaining: 9.82s
# 367:	learn: 0.0006232	total: 5.71s	remaining: 9.8s
# 368:	learn: 0.0006219	total: 5.72s	remaining: 9.79s
# 369:	learn: 0.0006194	total: 5.74s	remaining: 9.77s
# 370:	learn: 0.0006185	total: 5.75s	remaining: 9.76s
# 371:	learn: 0.0006168	total: 5.77s	remaining: 9.74s
# 372:	learn: 0.0006162	total: 5.78s	remaining: 9.72s
# 373:	learn: 0.0006149	total: 5.8s	remaining: 9.71s
# 374:	learn: 0.0006146	total: 5.81s	remaining: 9.69s
# 375:	learn: 0.0006132	total: 5.83s	remaining: 9.67s
# 376:	learn: 0.0006110	total: 5.85s	remaining: 9.66s
# 377:	learn: 0.0006084	total: 5.86s	remaining: 9.64s
# 378:	learn: 0.0006057	total: 5.88s	remaining: 9.63s
# 379:	learn: 0.0006031	total: 5.89s	remaining: 9.61s
# 380:	learn: 0.0006011	total: 5.91s	remaining: 9.6s
# 381:	learn: 0.0005988	total: 5.92s	remaining: 9.58s
# 382:	learn: 0.0005975	total: 5.94s	remaining: 9.57s
# 383:	learn: 0.0005951	total: 5.96s	remaining: 9.55s
# 384:	learn: 0.0005929	total: 5.97s	remaining: 9.54s
# 385:	learn: 0.0005920	total: 5.99s	remaining: 9.52s
# 386:	learn: 0.0005908	total: 6s	remaining: 9.51s
# 387:	learn: 0.0005891	total: 6.02s	remaining: 9.49s
# 388:	learn: 0.0005875	total: 6.03s	remaining: 9.47s
# 389:	learn: 0.0005863	total: 6.05s	remaining: 9.46s
# 390:	learn: 0.0005848	total: 6.06s	remaining: 9.44s
# 391:	learn: 0.0005840	total: 6.08s	remaining: 9.42s
# 392:	learn: 0.0005835	total: 6.09s	remaining: 9.41s
# 393:	learn: 0.0005825	total: 6.11s	remaining: 9.39s
# 394:	learn: 0.0005784	total: 6.12s	remaining: 9.38s
# 395:	learn: 0.0005754	total: 6.14s	remaining: 9.36s
# 396:	learn: 0.0005695	total: 6.15s	remaining: 9.35s
# 397:	learn: 0.0005683	total: 6.17s	remaining: 9.33s
# 398:	learn: 0.0005663	total: 6.18s	remaining: 9.31s
# 399:	learn: 0.0005637	total: 6.2s	remaining: 9.3s
# 400:	learn: 0.0005601	total: 6.21s	remaining: 9.28s
# 401:	learn: 0.0005585	total: 6.23s	remaining: 9.27s
# 402:	learn: 0.0005512	total: 6.24s	remaining: 9.25s
# 403:	learn: 0.0005498	total: 6.26s	remaining: 9.23s
# 404:	learn: 0.0005455	total: 6.27s	remaining: 9.22s
# 405:	learn: 0.0005440	total: 6.29s	remaining: 9.2s
# 406:	learn: 0.0005433	total: 6.3s	remaining: 9.18s
# 407:	learn: 0.0005426	total: 6.32s	remaining: 9.17s
# 408:	learn: 0.0005382	total: 6.33s	remaining: 9.15s
# 409:	learn: 0.0005368	total: 6.35s	remaining: 9.14s
# 410:	learn: 0.0005361	total: 6.36s	remaining: 9.12s
# 411:	learn: 0.0005349	total: 6.38s	remaining: 9.1s
# 412:	learn: 0.0005331	total: 6.39s	remaining: 9.09s
# 413:	learn: 0.0005311	total: 6.41s	remaining: 9.07s
# 414:	learn: 0.0005306	total: 6.42s	remaining: 9.05s
# 415:	learn: 0.0005295	total: 6.44s	remaining: 9.04s
# 416:	learn: 0.0005265	total: 6.45s	remaining: 9.02s
# 417:	learn: 0.0005224	total: 6.47s	remaining: 9.01s
# 418:	learn: 0.0005193	total: 6.48s	remaining: 8.99s
# 419:	learn: 0.0005176	total: 6.5s	remaining: 8.97s
# 420:	learn: 0.0005153	total: 6.51s	remaining: 8.96s
# 421:	learn: 0.0005128	total: 6.53s	remaining: 8.94s
# 422:	learn: 0.0005121	total: 6.54s	remaining: 8.93s
# 423:	learn: 0.0005094	total: 6.56s	remaining: 8.91s
# 424:	learn: 0.0005089	total: 6.57s	remaining: 8.89s
# 425:	learn: 0.0005071	total: 6.59s	remaining: 8.88s
# 426:	learn: 0.0005068	total: 6.6s	remaining: 8.86s
# 427:	learn: 0.0005055	total: 6.62s	remaining: 8.85s
# 428:	learn: 0.0005041	total: 6.63s	remaining: 8.83s
# 429:	learn: 0.0004985	total: 6.65s	remaining: 8.81s
# 430:	learn: 0.0004960	total: 6.67s	remaining: 8.8s
# 431:	learn: 0.0004934	total: 6.68s	remaining: 8.78s
# 432:	learn: 0.0004889	total: 6.7s	remaining: 8.77s
# 433:	learn: 0.0004875	total: 6.71s	remaining: 8.75s
# 434:	learn: 0.0004863	total: 6.72s	remaining: 8.73s
# 435:	learn: 0.0004834	total: 6.74s	remaining: 8.72s
# 436:	learn: 0.0004825	total: 6.75s	remaining: 8.7s
# 437:	learn: 0.0004821	total: 6.77s	remaining: 8.69s
# 438:	learn: 0.0004810	total: 6.78s	remaining: 8.67s
# 439:	learn: 0.0004783	total: 6.8s	remaining: 8.65s
# 440:	learn: 0.0004761	total: 6.81s	remaining: 8.64s
# 441:	learn: 0.0004757	total: 6.83s	remaining: 8.62s
# 442:	learn: 0.0004753	total: 6.84s	remaining: 8.6s
# 443:	learn: 0.0004748	total: 6.86s	remaining: 8.59s
# 444:	learn: 0.0004733	total: 6.87s	remaining: 8.57s
# 445:	learn: 0.0004712	total: 6.89s	remaining: 8.56s
# 446:	learn: 0.0004685	total: 6.9s	remaining: 8.54s
# 447:	learn: 0.0004682	total: 6.92s	remaining: 8.52s
# 448:	learn: 0.0004674	total: 6.93s	remaining: 8.51s
# 449:	learn: 0.0004669	total: 6.95s	remaining: 8.49s
# 450:	learn: 0.0004667	total: 6.96s	remaining: 8.48s
# 451:	learn: 0.0004651	total: 6.98s	remaining: 8.46s
# 452:	learn: 0.0004647	total: 6.99s	remaining: 8.45s
# 453:	learn: 0.0004634	total: 7.01s	remaining: 8.43s
# 454:	learn: 0.0004629	total: 7.03s	remaining: 8.41s
# 455:	learn: 0.0004620	total: 7.04s	remaining: 8.4s
# 456:	learn: 0.0004614	total: 7.05s	remaining: 8.38s
# 457:	learn: 0.0004602	total: 7.07s	remaining: 8.37s
# 458:	learn: 0.0004599	total: 7.09s	remaining: 8.35s
# 459:	learn: 0.0004591	total: 7.1s	remaining: 8.34s
# 460:	learn: 0.0004561	total: 7.12s	remaining: 8.32s
# 461:	learn: 0.0004554	total: 7.13s	remaining: 8.3s
# 462:	learn: 0.0004533	total: 7.14s	remaining: 8.29s
# 463:	learn: 0.0004514	total: 7.16s	remaining: 8.27s
# 464:	learn: 0.0004496	total: 7.18s	remaining: 8.26s
# 465:	learn: 0.0004484	total: 7.19s	remaining: 8.24s
# 466:	learn: 0.0004475	total: 7.21s	remaining: 8.23s
# 467:	learn: 0.0004465	total: 7.22s	remaining: 8.21s
# 468:	learn: 0.0004451	total: 7.24s	remaining: 8.2s
# 469:	learn: 0.0004437	total: 7.25s	remaining: 8.18s
# 470:	learn: 0.0004407	total: 7.27s	remaining: 8.16s
# 471:	learn: 0.0004393	total: 7.29s	remaining: 8.15s
# 472:	learn: 0.0004379	total: 7.3s	remaining: 8.13s
# 473:	learn: 0.0004363	total: 7.32s	remaining: 8.12s
# 474:	learn: 0.0004331	total: 7.33s	remaining: 8.1s
# 475:	learn: 0.0004321	total: 7.35s	remaining: 8.09s
# 476:	learn: 0.0004317	total: 7.36s	remaining: 8.07s
# 477:	learn: 0.0004307	total: 7.38s	remaining: 8.05s
# 478:	learn: 0.0004295	total: 7.39s	remaining: 8.04s
# 479:	learn: 0.0004286	total: 7.41s	remaining: 8.02s
# 480:	learn: 0.0004268	total: 7.42s	remaining: 8.01s
# 481:	learn: 0.0004264	total: 7.44s	remaining: 7.99s
# 482:	learn: 0.0004252	total: 7.45s	remaining: 7.97s
# 483:	learn: 0.0004246	total: 7.47s	remaining: 7.96s
# 484:	learn: 0.0004238	total: 7.48s	remaining: 7.94s
# 485:	learn: 0.0004225	total: 7.5s	remaining: 7.93s
# 486:	learn: 0.0004214	total: 7.51s	remaining: 7.91s
# 487:	learn: 0.0004203	total: 7.52s	remaining: 7.89s
# 488:	learn: 0.0004196	total: 7.54s	remaining: 7.88s
# 489:	learn: 0.0004189	total: 7.55s	remaining: 7.86s
# 490:	learn: 0.0004170	total: 7.57s	remaining: 7.85s
# 491:	learn: 0.0004162	total: 7.58s	remaining: 7.83s
# 492:	learn: 0.0004153	total: 7.6s	remaining: 7.82s
# 493:	learn: 0.0004147	total: 7.61s	remaining: 7.8s
# 494:	learn: 0.0004111	total: 7.63s	remaining: 7.78s
# 495:	learn: 0.0004069	total: 7.64s	remaining: 7.77s
# 496:	learn: 0.0004065	total: 7.66s	remaining: 7.75s
# 497:	learn: 0.0004058	total: 7.67s	remaining: 7.74s
# 498:	learn: 0.0004054	total: 7.69s	remaining: 7.72s
# 499:	learn: 0.0004031	total: 7.71s	remaining: 7.71s
# 500:	learn: 0.0004029	total: 7.72s	remaining: 7.69s
# 501:	learn: 0.0004025	total: 7.73s	remaining: 7.67s
# 502:	learn: 0.0004019	total: 7.75s	remaining: 7.66s
# 503:	learn: 0.0004004	total: 7.76s	remaining: 7.64s
# 504:	learn: 0.0003996	total: 7.78s	remaining: 7.63s
# 505:	learn: 0.0003995	total: 7.79s	remaining: 7.61s
# 506:	learn: 0.0003985	total: 7.81s	remaining: 7.59s
# 507:	learn: 0.0003979	total: 7.82s	remaining: 7.58s
# 508:	learn: 0.0003974	total: 7.84s	remaining: 7.56s
# 509:	learn: 0.0003970	total: 7.86s	remaining: 7.55s
# 510:	learn: 0.0003965	total: 7.87s	remaining: 7.53s
# 511:	learn: 0.0003961	total: 7.88s	remaining: 7.51s
# 512:	learn: 0.0003930	total: 7.9s	remaining: 7.5s
# 513:	learn: 0.0003928	total: 7.92s	remaining: 7.48s
# 514:	learn: 0.0003924	total: 7.93s	remaining: 7.47s
# 515:	learn: 0.0003904	total: 7.95s	remaining: 7.45s
# 516:	learn: 0.0003901	total: 7.96s	remaining: 7.44s
# 517:	learn: 0.0003893	total: 7.97s	remaining: 7.42s
# 518:	learn: 0.0003865	total: 7.99s	remaining: 7.4s
# 519:	learn: 0.0003852	total: 8s	remaining: 7.39s
# 520:	learn: 0.0003845	total: 8.02s	remaining: 7.37s
# 521:	learn: 0.0003844	total: 8.04s	remaining: 7.36s
# 522:	learn: 0.0003825	total: 8.05s	remaining: 7.34s
# 523:	learn: 0.0003799	total: 8.06s	remaining: 7.33s
# 524:	learn: 0.0003795	total: 8.08s	remaining: 7.31s
# 525:	learn: 0.0003789	total: 8.09s	remaining: 7.29s
# 526:	learn: 0.0003769	total: 8.11s	remaining: 7.28s
# 527:	learn: 0.0003757	total: 8.12s	remaining: 7.26s
# 528:	learn: 0.0003754	total: 8.14s	remaining: 7.25s
# 529:	learn: 0.0003744	total: 8.15s	remaining: 7.23s
# 530:	learn: 0.0003738	total: 8.17s	remaining: 7.21s
# 531:	learn: 0.0003727	total: 8.18s	remaining: 7.2s
# 532:	learn: 0.0003712	total: 8.2s	remaining: 7.18s
# 533:	learn: 0.0003696	total: 8.21s	remaining: 7.17s
# 534:	learn: 0.0003686	total: 8.23s	remaining: 7.15s
# 535:	learn: 0.0003683	total: 8.24s	remaining: 7.14s
# 536:	learn: 0.0003672	total: 8.26s	remaining: 7.12s
# 537:	learn: 0.0003663	total: 8.27s	remaining: 7.1s
# 538:	learn: 0.0003646	total: 8.29s	remaining: 7.09s
# 539:	learn: 0.0003642	total: 8.3s	remaining: 7.07s
# 540:	learn: 0.0003639	total: 8.32s	remaining: 7.05s
# 541:	learn: 0.0003611	total: 8.34s	remaining: 7.04s
# 542:	learn: 0.0003601	total: 8.35s	remaining: 7.03s
# 543:	learn: 0.0003584	total: 8.37s	remaining: 7.01s
# 544:	learn: 0.0003582	total: 8.38s	remaining: 7s
# 545:	learn: 0.0003573	total: 8.39s	remaining: 6.98s
# 546:	learn: 0.0003521	total: 8.41s	remaining: 6.96s
# 547:	learn: 0.0003517	total: 8.43s	remaining: 6.95s
# 548:	learn: 0.0003509	total: 8.44s	remaining: 6.94s
# 549:	learn: 0.0003496	total: 8.46s	remaining: 6.92s
# 550:	learn: 0.0003490	total: 8.47s	remaining: 6.91s
# 551:	learn: 0.0003470	total: 8.49s	remaining: 6.89s
# 552:	learn: 0.0003459	total: 8.5s	remaining: 6.87s
# 553:	learn: 0.0003453	total: 8.52s	remaining: 6.86s
# 554:	learn: 0.0003449	total: 8.53s	remaining: 6.84s
# 555:	learn: 0.0003446	total: 8.55s	remaining: 6.83s
# 556:	learn: 0.0003438	total: 8.56s	remaining: 6.81s
# 557:	learn: 0.0003422	total: 8.58s	remaining: 6.79s
# 558:	learn: 0.0003396	total: 8.59s	remaining: 6.78s
# 559:	learn: 0.0003393	total: 8.61s	remaining: 6.76s
# 560:	learn: 0.0003387	total: 8.62s	remaining: 6.75s
# 561:	learn: 0.0003382	total: 8.64s	remaining: 6.73s
# 562:	learn: 0.0003370	total: 8.65s	remaining: 6.72s
# 563:	learn: 0.0003349	total: 8.67s	remaining: 6.7s
# 564:	learn: 0.0003332	total: 8.68s	remaining: 6.68s
# 565:	learn: 0.0003328	total: 8.7s	remaining: 6.67s
# 566:	learn: 0.0003323	total: 8.71s	remaining: 6.65s
# 567:	learn: 0.0003323	total: 8.72s	remaining: 6.63s
# 568:	learn: 0.0003321	total: 8.74s	remaining: 6.62s
# 569:	learn: 0.0003313	total: 8.75s	remaining: 6.6s
# 570:	learn: 0.0003313	total: 8.77s	remaining: 6.59s
# 571:	learn: 0.0003297	total: 8.78s	remaining: 6.57s
# 572:	learn: 0.0003291	total: 8.79s	remaining: 6.55s
# 573:	learn: 0.0003281	total: 8.81s	remaining: 6.54s
# 574:	learn: 0.0003277	total: 8.82s	remaining: 6.52s
# 575:	learn: 0.0003253	total: 8.84s	remaining: 6.51s
# 576:	learn: 0.0003242	total: 8.85s	remaining: 6.49s
# 577:	learn: 0.0003202	total: 8.87s	remaining: 6.47s
# 578:	learn: 0.0003195	total: 8.88s	remaining: 6.46s
# 579:	learn: 0.0003180	total: 8.9s	remaining: 6.44s
# 580:	learn: 0.0003178	total: 8.91s	remaining: 6.43s
# 581:	learn: 0.0003175	total: 8.93s	remaining: 6.41s
# 582:	learn: 0.0003165	total: 8.94s	remaining: 6.39s
# 583:	learn: 0.0003162	total: 8.96s	remaining: 6.38s
# 584:	learn: 0.0003150	total: 8.97s	remaining: 6.36s
# 585:	learn: 0.0003140	total: 8.99s	remaining: 6.35s
# 586:	learn: 0.0003124	total: 9s	remaining: 6.33s
# 587:	learn: 0.0003108	total: 9.02s	remaining: 6.32s
# 588:	learn: 0.0003102	total: 9.03s	remaining: 6.3s
# 589:	learn: 0.0003098	total: 9.05s	remaining: 6.29s
# 590:	learn: 0.0003084	total: 9.06s	remaining: 6.27s
# 591:	learn: 0.0003082	total: 9.07s	remaining: 6.25s
# 592:	learn: 0.0003075	total: 9.09s	remaining: 6.24s
# 593:	learn: 0.0003062	total: 9.1s	remaining: 6.22s
# 594:	learn: 0.0003056	total: 9.12s	remaining: 6.21s
# 595:	learn: 0.0003047	total: 9.13s	remaining: 6.19s
# 596:	learn: 0.0003044	total: 9.15s	remaining: 6.17s
# 597:	learn: 0.0003037	total: 9.16s	remaining: 6.16s
# 598:	learn: 0.0003024	total: 9.18s	remaining: 6.14s
# 599:	learn: 0.0003004	total: 9.19s	remaining: 6.13s
# 600:	learn: 0.0002996	total: 9.21s	remaining: 6.11s
# 601:	learn: 0.0002995	total: 9.28s	remaining: 6.14s
# 602:	learn: 0.0002994	total: 9.3s	remaining: 6.12s
# 603:	learn: 0.0002982	total: 9.31s	remaining: 6.11s
# 604:	learn: 0.0002978	total: 9.33s	remaining: 6.09s
# 605:	learn: 0.0002921	total: 9.34s	remaining: 6.08s
# 606:	learn: 0.0002903	total: 9.36s	remaining: 6.06s
# 607:	learn: 0.0002899	total: 9.37s	remaining: 6.04s
# 608:	learn: 0.0002891	total: 9.39s	remaining: 6.03s
# 609:	learn: 0.0002888	total: 9.4s	remaining: 6.01s
# 610:	learn: 0.0002873	total: 9.42s	remaining: 6s
# 611:	learn: 0.0002868	total: 9.44s	remaining: 5.98s
# 612:	learn: 0.0002862	total: 9.45s	remaining: 5.97s
# 613:	learn: 0.0002848	total: 9.47s	remaining: 5.95s
# 614:	learn: 0.0002828	total: 9.48s	remaining: 5.93s
# 615:	learn: 0.0002805	total: 9.5s	remaining: 5.92s
# 616:	learn: 0.0002799	total: 9.51s	remaining: 5.9s
# 617:	learn: 0.0002792	total: 9.53s	remaining: 5.89s
# 618:	learn: 0.0002782	total: 9.54s	remaining: 5.87s
# 619:	learn: 0.0002780	total: 9.55s	remaining: 5.86s
# 620:	learn: 0.0002768	total: 9.57s	remaining: 5.84s
# 621:	learn: 0.0002766	total: 9.59s	remaining: 5.83s
# 622:	learn: 0.0002764	total: 9.6s	remaining: 5.81s
# 623:	learn: 0.0002761	total: 9.61s	remaining: 5.79s
# 624:	learn: 0.0002758	total: 9.63s	remaining: 5.78s
# 625:	learn: 0.0002755	total: 9.64s	remaining: 5.76s
# 626:	learn: 0.0002748	total: 9.66s	remaining: 5.75s
# 627:	learn: 0.0002741	total: 9.68s	remaining: 5.73s
# 628:	learn: 0.0002734	total: 9.69s	remaining: 5.72s
# 629:	learn: 0.0002733	total: 9.71s	remaining: 5.7s
# 630:	learn: 0.0002732	total: 9.72s	remaining: 5.69s
# 631:	learn: 0.0002722	total: 9.74s	remaining: 5.67s
# 632:	learn: 0.0002717	total: 9.76s	remaining: 5.66s
# 633:	learn: 0.0002704	total: 9.77s	remaining: 5.64s
# 634:	learn: 0.0002679	total: 9.79s	remaining: 5.63s
# 635:	learn: 0.0002670	total: 9.8s	remaining: 5.61s
# 636:	learn: 0.0002665	total: 9.81s	remaining: 5.59s
# 637:	learn: 0.0002645	total: 9.83s	remaining: 5.58s
# 638:	learn: 0.0002643	total: 9.85s	remaining: 5.56s
# 639:	learn: 0.0002642	total: 9.86s	remaining: 5.55s
# 640:	learn: 0.0002639	total: 9.87s	remaining: 5.53s
# 641:	learn: 0.0002634	total: 9.89s	remaining: 5.51s
# 642:	learn: 0.0002627	total: 9.9s	remaining: 5.5s
# 643:	learn: 0.0002618	total: 9.92s	remaining: 5.48s
# 644:	learn: 0.0002614	total: 9.93s	remaining: 5.47s
# 645:	learn: 0.0002602	total: 9.95s	remaining: 5.45s
# 646:	learn: 0.0002589	total: 9.96s	remaining: 5.44s
# 647:	learn: 0.0002578	total: 9.98s	remaining: 5.42s
# 648:	learn: 0.0002577	total: 9.99s	remaining: 5.4s
# 649:	learn: 0.0002573	total: 10s	remaining: 5.39s
# 650:	learn: 0.0002531	total: 10s	remaining: 5.37s
# 651:	learn: 0.0002530	total: 10s	remaining: 5.36s
# 652:	learn: 0.0002525	total: 10.1s	remaining: 5.34s
# 653:	learn: 0.0002522	total: 10.1s	remaining: 5.33s
# 654:	learn: 0.0002520	total: 10.1s	remaining: 5.31s
# 655:	learn: 0.0002515	total: 10.1s	remaining: 5.3s
# 656:	learn: 0.0002515	total: 10.1s	remaining: 5.28s
# 657:	learn: 0.0002514	total: 10.1s	remaining: 5.26s
# 658:	learn: 0.0002508	total: 10.1s	remaining: 5.25s
# 659:	learn: 0.0002502	total: 10.2s	remaining: 5.23s
# 660:	learn: 0.0002500	total: 10.2s	remaining: 5.21s
# 661:	learn: 0.0002492	total: 10.2s	remaining: 5.2s
# 662:	learn: 0.0002492	total: 10.2s	remaining: 5.18s
# 663:	learn: 0.0002492	total: 10.2s	remaining: 5.17s
# 664:	learn: 0.0002485	total: 10.2s	remaining: 5.15s
# 665:	learn: 0.0002480	total: 10.2s	remaining: 5.13s
# 666:	learn: 0.0002478	total: 10.3s	remaining: 5.12s
# 667:	learn: 0.0002476	total: 10.3s	remaining: 5.1s
# 668:	learn: 0.0002472	total: 10.3s	remaining: 5.09s
# 669:	learn: 0.0002444	total: 10.3s	remaining: 5.07s
# 670:	learn: 0.0002420	total: 10.3s	remaining: 5.06s
# 671:	learn: 0.0002413	total: 10.3s	remaining: 5.04s
# 672:	learn: 0.0002411	total: 10.3s	remaining: 5.03s
# 673:	learn: 0.0002410	total: 10.4s	remaining: 5.01s
# 674:	learn: 0.0002398	total: 10.4s	remaining: 4.99s
# 675:	learn: 0.0002363	total: 10.4s	remaining: 4.98s
# 676:	learn: 0.0002348	total: 10.4s	remaining: 4.96s
# 677:	learn: 0.0002347	total: 10.4s	remaining: 4.95s
# 678:	learn: 0.0002328	total: 10.4s	remaining: 4.93s
# 679:	learn: 0.0002328	total: 10.4s	remaining: 4.92s
# 680:	learn: 0.0002314	total: 10.5s	remaining: 4.9s
# 681:	learn: 0.0002312	total: 10.5s	remaining: 4.88s
# 682:	learn: 0.0002311	total: 10.5s	remaining: 4.87s
# 683:	learn: 0.0002307	total: 10.5s	remaining: 4.85s
# 684:	learn: 0.0002294	total: 10.5s	remaining: 4.84s
# 685:	learn: 0.0002269	total: 10.5s	remaining: 4.82s
# 686:	learn: 0.0002267	total: 10.6s	remaining: 4.81s
# 687:	learn: 0.0002262	total: 10.6s	remaining: 4.79s
# 688:	learn: 0.0002254	total: 10.6s	remaining: 4.78s
# 689:	learn: 0.0002245	total: 10.6s	remaining: 4.76s
# 690:	learn: 0.0002244	total: 10.6s	remaining: 4.75s
# 691:	learn: 0.0002242	total: 10.6s	remaining: 4.73s
# 692:	learn: 0.0002240	total: 10.6s	remaining: 4.71s
# 693:	learn: 0.0002238	total: 10.7s	remaining: 4.7s
# 694:	learn: 0.0002238	total: 10.7s	remaining: 4.68s
# 695:	learn: 0.0002213	total: 10.7s	remaining: 4.67s
# 696:	learn: 0.0002212	total: 10.7s	remaining: 4.65s
# 697:	learn: 0.0002206	total: 10.7s	remaining: 4.64s
# 698:	learn: 0.0002205	total: 10.7s	remaining: 4.62s
# 699:	learn: 0.0002202	total: 10.8s	remaining: 4.61s
# 700:	learn: 0.0002196	total: 10.8s	remaining: 4.59s
# 701:	learn: 0.0002195	total: 10.8s	remaining: 4.58s
# 702:	learn: 0.0002188	total: 10.8s	remaining: 4.56s
# 703:	learn: 0.0002186	total: 10.8s	remaining: 4.54s
# 704:	learn: 0.0002174	total: 10.8s	remaining: 4.53s
# 705:	learn: 0.0002166	total: 10.8s	remaining: 4.51s
# 706:	learn: 0.0002162	total: 10.9s	remaining: 4.5s
# 707:	learn: 0.0002162	total: 10.9s	remaining: 4.48s
# 708:	learn: 0.0002158	total: 10.9s	remaining: 4.47s
# 709:	learn: 0.0002154	total: 10.9s	remaining: 4.45s
# 710:	learn: 0.0002152	total: 10.9s	remaining: 4.44s
# 711:	learn: 0.0002148	total: 10.9s	remaining: 4.42s
# 712:	learn: 0.0002148	total: 10.9s	remaining: 4.41s
# 713:	learn: 0.0002144	total: 11s	remaining: 4.39s
# 714:	learn: 0.0002132	total: 11s	remaining: 4.38s
# 715:	learn: 0.0002130	total: 11s	remaining: 4.36s
# 716:	learn: 0.0002110	total: 11s	remaining: 4.34s
# 717:	learn: 0.0002100	total: 11s	remaining: 4.33s
# 718:	learn: 0.0002097	total: 11s	remaining: 4.31s
# 719:	learn: 0.0002096	total: 11.1s	remaining: 4.3s
# 720:	learn: 0.0002094	total: 11.1s	remaining: 4.28s
# 721:	learn: 0.0002087	total: 11.1s	remaining: 4.27s
# 722:	learn: 0.0002081	total: 11.1s	remaining: 4.25s
# 723:	learn: 0.0002073	total: 11.1s	remaining: 4.24s
# 724:	learn: 0.0002067	total: 11.1s	remaining: 4.22s
# 725:	learn: 0.0002059	total: 11.1s	remaining: 4.21s
# 726:	learn: 0.0002052	total: 11.2s	remaining: 4.19s
# 727:	learn: 0.0002050	total: 11.2s	remaining: 4.17s
# 728:	learn: 0.0002047	total: 11.2s	remaining: 4.16s
# 729:	learn: 0.0002044	total: 11.2s	remaining: 4.14s
# 730:	learn: 0.0002039	total: 11.2s	remaining: 4.13s
# 731:	learn: 0.0002036	total: 11.2s	remaining: 4.11s
# 732:	learn: 0.0002031	total: 11.2s	remaining: 4.1s
# 733:	learn: 0.0002031	total: 11.3s	remaining: 4.08s
# 734:	learn: 0.0002029	total: 11.3s	remaining: 4.07s
# 735:	learn: 0.0002026	total: 11.3s	remaining: 4.05s
# 736:	learn: 0.0002014	total: 11.3s	remaining: 4.04s
# 737:	learn: 0.0002010	total: 11.3s	remaining: 4.02s
# 738:	learn: 0.0002009	total: 11.3s	remaining: 4s
# 739:	learn: 0.0002006	total: 11.4s	remaining: 3.99s
# 740:	learn: 0.0002003	total: 11.4s	remaining: 3.97s
# 741:	learn: 0.0001997	total: 11.4s	remaining: 3.96s
# 742:	learn: 0.0001994	total: 11.4s	remaining: 3.94s
# 743:	learn: 0.0001994	total: 11.4s	remaining: 3.93s
# 744:	learn: 0.0001991	total: 11.4s	remaining: 3.91s
# 745:	learn: 0.0001982	total: 11.4s	remaining: 3.9s
# 746:	learn: 0.0001979	total: 11.5s	remaining: 3.88s
# 747:	learn: 0.0001972	total: 11.5s	remaining: 3.86s
# 748:	learn: 0.0001970	total: 11.5s	remaining: 3.85s
# 749:	learn: 0.0001961	total: 11.5s	remaining: 3.83s
# 750:	learn: 0.0001941	total: 11.5s	remaining: 3.82s
# 751:	learn: 0.0001939	total: 11.5s	remaining: 3.8s
# 752:	learn: 0.0001935	total: 11.5s	remaining: 3.79s
# 753:	learn: 0.0001913	total: 11.6s	remaining: 3.77s
# 754:	learn: 0.0001912	total: 11.6s	remaining: 3.76s
# 755:	learn: 0.0001911	total: 11.6s	remaining: 3.74s
# 756:	learn: 0.0001909	total: 11.6s	remaining: 3.73s
# 757:	learn: 0.0001906	total: 11.6s	remaining: 3.71s
# 758:	learn: 0.0001905	total: 11.6s	remaining: 3.69s
# 759:	learn: 0.0001891	total: 11.7s	remaining: 3.68s
# 760:	learn: 0.0001885	total: 11.7s	remaining: 3.66s
# 761:	learn: 0.0001883	total: 11.7s	remaining: 3.65s
# 762:	learn: 0.0001878	total: 11.7s	remaining: 3.63s
# 763:	learn: 0.0001877	total: 11.7s	remaining: 3.62s
# 764:	learn: 0.0001875	total: 11.7s	remaining: 3.6s
# 765:	learn: 0.0001873	total: 11.7s	remaining: 3.59s
# 766:	learn: 0.0001871	total: 11.8s	remaining: 3.57s
# 767:	learn: 0.0001862	total: 11.8s	remaining: 3.56s
# 768:	learn: 0.0001861	total: 11.8s	remaining: 3.54s
# 769:	learn: 0.0001859	total: 11.8s	remaining: 3.52s
# 770:	learn: 0.0001854	total: 11.8s	remaining: 3.51s
# 771:	learn: 0.0001853	total: 11.8s	remaining: 3.49s
# 772:	learn: 0.0001849	total: 11.8s	remaining: 3.48s
# 773:	learn: 0.0001842	total: 11.9s	remaining: 3.46s
# 774:	learn: 0.0001835	total: 11.9s	remaining: 3.45s
# 775:	learn: 0.0001833	total: 11.9s	remaining: 3.43s
# 776:	learn: 0.0001830	total: 11.9s	remaining: 3.42s
# 777:	learn: 0.0001826	total: 11.9s	remaining: 3.4s
# 778:	learn: 0.0001825	total: 11.9s	remaining: 3.39s
# 779:	learn: 0.0001822	total: 12s	remaining: 3.37s
# 780:	learn: 0.0001816	total: 12s	remaining: 3.36s
# 781:	learn: 0.0001813	total: 12s	remaining: 3.34s
# 782:	learn: 0.0001807	total: 12s	remaining: 3.33s
# 783:	learn: 0.0001807	total: 12s	remaining: 3.31s
# 784:	learn: 0.0001802	total: 12s	remaining: 3.29s
# 785:	learn: 0.0001801	total: 12s	remaining: 3.28s
# 786:	learn: 0.0001793	total: 12.1s	remaining: 3.26s
# 787:	learn: 0.0001792	total: 12.1s	remaining: 3.25s
# 788:	learn: 0.0001788	total: 12.1s	remaining: 3.23s
# 789:	learn: 0.0001784	total: 12.1s	remaining: 3.22s
# 790:	learn: 0.0001781	total: 12.1s	remaining: 3.2s
# 791:	learn: 0.0001779	total: 12.1s	remaining: 3.19s
# 792:	learn: 0.0001775	total: 12.2s	remaining: 3.17s
# 793:	learn: 0.0001774	total: 12.2s	remaining: 3.16s
# 794:	learn: 0.0001770	total: 12.2s	remaining: 3.14s
# 795:	learn: 0.0001769	total: 12.2s	remaining: 3.13s
# 796:	learn: 0.0001768	total: 12.2s	remaining: 3.11s
# 797:	learn: 0.0001764	total: 12.2s	remaining: 3.1s
# 798:	learn: 0.0001759	total: 12.2s	remaining: 3.08s
# 799:	learn: 0.0001755	total: 12.3s	remaining: 3.06s
# 800:	learn: 0.0001751	total: 12.3s	remaining: 3.05s
# 801:	learn: 0.0001746	total: 12.3s	remaining: 3.03s
# 802:	learn: 0.0001742	total: 12.3s	remaining: 3.02s
# 803:	learn: 0.0001739	total: 12.3s	remaining: 3s
# 804:	learn: 0.0001734	total: 12.3s	remaining: 2.99s
# 805:	learn: 0.0001732	total: 12.3s	remaining: 2.97s
# 806:	learn: 0.0001729	total: 12.4s	remaining: 2.96s
# 807:	learn: 0.0001724	total: 12.4s	remaining: 2.94s
# 808:	learn: 0.0001718	total: 12.4s	remaining: 2.93s
# 809:	learn: 0.0001715	total: 12.4s	remaining: 2.91s
# 810:	learn: 0.0001709	total: 12.4s	remaining: 2.9s
# 811:	learn: 0.0001708	total: 12.4s	remaining: 2.88s
# 812:	learn: 0.0001704	total: 12.5s	remaining: 2.86s
# 813:	learn: 0.0001700	total: 12.5s	remaining: 2.85s
# 814:	learn: 0.0001699	total: 12.5s	remaining: 2.83s
# 815:	learn: 0.0001695	total: 12.5s	remaining: 2.82s
# 816:	learn: 0.0001685	total: 12.5s	remaining: 2.8s
# 817:	learn: 0.0001685	total: 12.5s	remaining: 2.79s
# 818:	learn: 0.0001683	total: 12.5s	remaining: 2.77s
# 819:	learn: 0.0001680	total: 12.6s	remaining: 2.76s
# 820:	learn: 0.0001678	total: 12.6s	remaining: 2.74s
# 821:	learn: 0.0001675	total: 12.6s	remaining: 2.73s
# 822:	learn: 0.0001671	total: 12.6s	remaining: 2.71s
# 823:	learn: 0.0001669	total: 12.6s	remaining: 2.69s
# 824:	learn: 0.0001663	total: 12.6s	remaining: 2.68s
# 825:	learn: 0.0001661	total: 12.7s	remaining: 2.66s
# 826:	learn: 0.0001653	total: 12.7s	remaining: 2.65s
# 827:	learn: 0.0001648	total: 12.7s	remaining: 2.63s
# 828:	learn: 0.0001647	total: 12.7s	remaining: 2.62s
# 829:	learn: 0.0001646	total: 12.7s	remaining: 2.6s
# 830:	learn: 0.0001644	total: 12.7s	remaining: 2.59s
# 831:	learn: 0.0001641	total: 12.7s	remaining: 2.57s
# 832:	learn: 0.0001637	total: 12.8s	remaining: 2.56s
# 833:	learn: 0.0001637	total: 12.8s	remaining: 2.54s
# 834:	learn: 0.0001636	total: 12.8s	remaining: 2.53s
# 835:	learn: 0.0001635	total: 12.8s	remaining: 2.51s
# 836:	learn: 0.0001630	total: 12.8s	remaining: 2.5s
# 837:	learn: 0.0001628	total: 12.8s	remaining: 2.48s
# 838:	learn: 0.0001620	total: 12.8s	remaining: 2.46s
# 839:	learn: 0.0001618	total: 12.9s	remaining: 2.45s
# 840:	learn: 0.0001615	total: 12.9s	remaining: 2.43s
# 841:	learn: 0.0001611	total: 12.9s	remaining: 2.42s
# 842:	learn: 0.0001608	total: 12.9s	remaining: 2.4s
# 843:	learn: 0.0001606	total: 12.9s	remaining: 2.39s
# 844:	learn: 0.0001605	total: 12.9s	remaining: 2.37s
# 845:	learn: 0.0001596	total: 12.9s	remaining: 2.36s
# 846:	learn: 0.0001595	total: 13s	remaining: 2.34s
# 847:	learn: 0.0001586	total: 13s	remaining: 2.33s
# 848:	learn: 0.0001583	total: 13s	remaining: 2.31s
# 849:	learn: 0.0001582	total: 13s	remaining: 2.29s
# 850:	learn: 0.0001577	total: 13s	remaining: 2.28s
# 851:	learn: 0.0001576	total: 13s	remaining: 2.26s
# 852:	learn: 0.0001574	total: 13.1s	remaining: 2.25s
# 853:	learn: 0.0001573	total: 13.1s	remaining: 2.23s
# 854:	learn: 0.0001571	total: 13.1s	remaining: 2.22s
# 855:	learn: 0.0001569	total: 13.1s	remaining: 2.2s
# 856:	learn: 0.0001569	total: 13.1s	remaining: 2.19s
# 857:	learn: 0.0001567	total: 13.1s	remaining: 2.17s
# 858:	learn: 0.0001565	total: 13.1s	remaining: 2.16s
# 859:	learn: 0.0001564	total: 13.2s	remaining: 2.14s
# 860:	learn: 0.0001563	total: 13.2s	remaining: 2.13s
# 861:	learn: 0.0001561	total: 13.2s	remaining: 2.11s
# 862:	learn: 0.0001555	total: 13.2s	remaining: 2.1s
# 863:	learn: 0.0001554	total: 13.2s	remaining: 2.08s
# 864:	learn: 0.0001550	total: 13.2s	remaining: 2.06s
# 865:	learn: 0.0001550	total: 13.2s	remaining: 2.05s
# 866:	learn: 0.0001550	total: 13.3s	remaining: 2.03s
# 867:	learn: 0.0001550	total: 13.3s	remaining: 2.02s
# 868:	learn: 0.0001549	total: 13.3s	remaining: 2s
# 869:	learn: 0.0001544	total: 13.3s	remaining: 1.99s
# 870:	learn: 0.0001541	total: 13.3s	remaining: 1.97s
# 871:	learn: 0.0001539	total: 13.3s	remaining: 1.96s
# 872:	learn: 0.0001537	total: 13.3s	remaining: 1.94s
# 873:	learn: 0.0001537	total: 13.3s	remaining: 1.92s
# 874:	learn: 0.0001534	total: 13.4s	remaining: 1.91s
# 875:	learn: 0.0001528	total: 13.4s	remaining: 1.89s
# 876:	learn: 0.0001527	total: 13.4s	remaining: 1.88s
# 877:	learn: 0.0001525	total: 13.4s	remaining: 1.86s
# 878:	learn: 0.0001520	total: 13.4s	remaining: 1.85s
# 879:	learn: 0.0001512	total: 13.4s	remaining: 1.83s
# 880:	learn: 0.0001511	total: 13.5s	remaining: 1.82s
# 881:	learn: 0.0001509	total: 13.5s	remaining: 1.8s
# 882:	learn: 0.0001508	total: 13.5s	remaining: 1.79s
# 883:	learn: 0.0001505	total: 13.5s	remaining: 1.77s
# 884:	learn: 0.0001503	total: 13.5s	remaining: 1.76s
# 885:	learn: 0.0001500	total: 13.5s	remaining: 1.74s
# 886:	learn: 0.0001498	total: 13.6s	remaining: 1.73s
# 887:	learn: 0.0001497	total: 13.6s	remaining: 1.71s
# 888:	learn: 0.0001495	total: 13.6s	remaining: 1.7s
# 889:	learn: 0.0001493	total: 13.6s	remaining: 1.68s
# 890:	learn: 0.0001491	total: 13.6s	remaining: 1.67s
# 891:	learn: 0.0001490	total: 13.6s	remaining: 1.65s
# 892:	learn: 0.0001488	total: 13.6s	remaining: 1.63s
# 893:	learn: 0.0001484	total: 13.7s	remaining: 1.62s
# 894:	learn: 0.0001482	total: 13.7s	remaining: 1.6s
# 895:	learn: 0.0001479	total: 13.7s	remaining: 1.59s
# 896:	learn: 0.0001477	total: 13.7s	remaining: 1.57s
# 897:	learn: 0.0001470	total: 13.7s	remaining: 1.56s
# 898:	learn: 0.0001469	total: 13.7s	remaining: 1.54s
# 899:	learn: 0.0001467	total: 13.7s	remaining: 1.53s
# 900:	learn: 0.0001463	total: 13.8s	remaining: 1.51s
# 901:	learn: 0.0001461	total: 13.8s	remaining: 1.5s
# 902:	learn: 0.0001459	total: 13.8s	remaining: 1.48s
# 903:	learn: 0.0001456	total: 13.8s	remaining: 1.47s
# 904:	learn: 0.0001454	total: 13.8s	remaining: 1.45s
# 905:	learn: 0.0001453	total: 13.8s	remaining: 1.44s
# 906:	learn: 0.0001451	total: 13.8s	remaining: 1.42s
# 907:	learn: 0.0001449	total: 13.9s	remaining: 1.4s
# 908:	learn: 0.0001447	total: 13.9s	remaining: 1.39s
# 909:	learn: 0.0001437	total: 13.9s	remaining: 1.37s
# 910:	learn: 0.0001435	total: 13.9s	remaining: 1.36s
# 911:	learn: 0.0001435	total: 13.9s	remaining: 1.34s
# 912:	learn: 0.0001434	total: 13.9s	remaining: 1.33s
# 913:	learn: 0.0001429	total: 14s	remaining: 1.31s
# 914:	learn: 0.0001428	total: 14s	remaining: 1.3s
# 915:	learn: 0.0001427	total: 14s	remaining: 1.28s
# 916:	learn: 0.0001426	total: 14s	remaining: 1.27s
# 917:	learn: 0.0001425	total: 14s	remaining: 1.25s
# 918:	learn: 0.0001422	total: 14s	remaining: 1.24s
# 919:	learn: 0.0001416	total: 14s	remaining: 1.22s
# 920:	learn: 0.0001413	total: 14.1s	remaining: 1.21s
# 921:	learn: 0.0001406	total: 14.1s	remaining: 1.19s
# 922:	learn: 0.0001405	total: 14.1s	remaining: 1.18s
# 923:	learn: 0.0001403	total: 14.1s	remaining: 1.16s
# 924:	learn: 0.0001401	total: 14.1s	remaining: 1.14s
# 925:	learn: 0.0001399	total: 14.1s	remaining: 1.13s
# 926:	learn: 0.0001398	total: 14.1s	remaining: 1.11s
# 927:	learn: 0.0001396	total: 14.2s	remaining: 1.1s
# 928:	learn: 0.0001394	total: 14.2s	remaining: 1.08s
# 929:	learn: 0.0001392	total: 14.2s	remaining: 1.07s
# 930:	learn: 0.0001391	total: 14.2s	remaining: 1.05s
# 931:	learn: 0.0001381	total: 14.2s	remaining: 1.04s
# 932:	learn: 0.0001378	total: 14.2s	remaining: 1.02s
# 933:	learn: 0.0001377	total: 14.2s	remaining: 1.01s
# 934:	learn: 0.0001375	total: 14.3s	remaining: 992ms
# 935:	learn: 0.0001372	total: 14.3s	remaining: 976ms
# 936:	learn: 0.0001370	total: 14.3s	remaining: 961ms
# 937:	learn: 0.0001369	total: 14.3s	remaining: 946ms
# 938:	learn: 0.0001368	total: 14.3s	remaining: 930ms
# 939:	learn: 0.0001368	total: 14.3s	remaining: 915ms
# 940:	learn: 0.0001365	total: 14.4s	remaining: 900ms
# 941:	learn: 0.0001364	total: 14.4s	remaining: 885ms
# 942:	learn: 0.0001362	total: 14.4s	remaining: 869ms
# 943:	learn: 0.0001362	total: 14.4s	remaining: 854ms
# 944:	learn: 0.0001359	total: 14.4s	remaining: 839ms
# 945:	learn: 0.0001359	total: 14.4s	remaining: 823ms
# 946:	learn: 0.0001358	total: 14.4s	remaining: 808ms
# 947:	learn: 0.0001356	total: 14.5s	remaining: 793ms
# 948:	learn: 0.0001354	total: 14.5s	remaining: 778ms
# 949:	learn: 0.0001353	total: 14.5s	remaining: 762ms
# 950:	learn: 0.0001351	total: 14.5s	remaining: 747ms
# 951:	learn: 0.0001348	total: 14.5s	remaining: 732ms
# 952:	learn: 0.0001343	total: 14.5s	remaining: 716ms
# 953:	learn: 0.0001341	total: 14.5s	remaining: 701ms
# 954:	learn: 0.0001339	total: 14.6s	remaining: 686ms
# 955:	learn: 0.0001338	total: 14.6s	remaining: 671ms
# 956:	learn: 0.0001338	total: 14.6s	remaining: 655ms
# 957:	learn: 0.0001335	total: 14.6s	remaining: 640ms
# 958:	learn: 0.0001332	total: 14.6s	remaining: 625ms
# 959:	learn: 0.0001330	total: 14.6s	remaining: 610ms
# 960:	learn: 0.0001326	total: 14.6s	remaining: 594ms
# 961:	learn: 0.0001324	total: 14.7s	remaining: 579ms
# 962:	learn: 0.0001323	total: 14.7s	remaining: 564ms
# 963:	learn: 0.0001314	total: 14.7s	remaining: 549ms
# 964:	learn: 0.0001313	total: 14.7s	remaining: 534ms
# 965:	learn: 0.0001306	total: 14.7s	remaining: 518ms
# 966:	learn: 0.0001305	total: 14.7s	remaining: 503ms
# 967:	learn: 0.0001305	total: 14.8s	remaining: 488ms
# 968:	learn: 0.0001303	total: 14.8s	remaining: 473ms
# 969:	learn: 0.0001301	total: 14.8s	remaining: 457ms
# 970:	learn: 0.0001301	total: 14.8s	remaining: 442ms
# 971:	learn: 0.0001300	total: 14.8s	remaining: 427ms
# 972:	learn: 0.0001299	total: 14.8s	remaining: 412ms
# 973:	learn: 0.0001298	total: 14.8s	remaining: 396ms
# 974:	learn: 0.0001297	total: 14.9s	remaining: 381ms
# 975:	learn: 0.0001295	total: 14.9s	remaining: 366ms
# 976:	learn: 0.0001289	total: 14.9s	remaining: 351ms
# 977:	learn: 0.0001288	total: 14.9s	remaining: 335ms
# 978:	learn: 0.0001286	total: 14.9s	remaining: 320ms
# 979:	learn: 0.0001284	total: 14.9s	remaining: 305ms
# 980:	learn: 0.0001282	total: 14.9s	remaining: 290ms
# 981:	learn: 0.0001282	total: 15s	remaining: 274ms
# 982:	learn: 0.0001282	total: 15s	remaining: 259ms
# 983:	learn: 0.0001281	total: 15s	remaining: 244ms
# 984:	learn: 0.0001281	total: 15s	remaining: 228ms
# 985:	learn: 0.0001281	total: 15s	remaining: 213ms
# 986:	learn: 0.0001281	total: 15s	remaining: 198ms
# 987:	learn: 0.0001281	total: 15s	remaining: 183ms
# 988:	learn: 0.0001281	total: 15s	remaining: 167ms
# 989:	learn: 0.0001281	total: 15s	remaining: 152ms
# 990:	learn: 0.0001281	total: 15.1s	remaining: 137ms
# 991:	learn: 0.0001281	total: 15.1s	remaining: 122ms
# 992:	learn: 0.0001281	total: 15.1s	remaining: 106ms
# 993:	learn: 0.0001281	total: 15.1s	remaining: 91.1ms
# 994:	learn: 0.0001281	total: 15.1s	remaining: 75.9ms
# 995:	learn: 0.0001281	total: 15.1s	remaining: 60.7ms
# 996:	learn: 0.0001281	total: 15.1s	remaining: 45.5ms
# 997:	learn: 0.0001281	total: 15.1s	remaining: 30.3ms
# 998:	learn: 0.0001281	total: 15.1s	remaining: 15.2ms
# 999:	learn: 0.0001281	total: 15.1s	remaining: 0us
# 0.9994382219725431

# %%
cat_clf = catboost.CatBoostClassifier()
cat_clf.fit(X_train, y_train)

y_pred = cat_clf.predict(X_test)
print('undersampling accuracy:', accuracy_score(y_test_un, y_pred_un))

# %%
cat_clf = catboost.CatBoostClassifier()
cat_clf.fit(X_train, y_train)

y_pred = cat_clf.predict(X_test)
print('oversampling accuracy:', accuracy_score(y_test_ov, y_pred_ov))

# %% [markdown]
# ## Bagging

# %%
bag_clf = BaggingClassifier(
    LogisticRegression(max_iter=100000), 
    n_estimators = 500, 
    max_samples = 100, 
    bootstrap = True, 
    n_jobs = -1
)

bag_clf.fit(X_train, y_train)

y_pred = bag_clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9982444436641972

# %%
bag_clf = BaggingClassifier()

bag_clf.fit(X_train, y_train)

y_pred = bag_clf.predict(X_test)
print('accuracy:', accuracy_score(y_test, y_pred))

# %%
bag_clf = BaggingClassifier()

bag_clf.fit(X_train_un, y_train_un)

y_pred_un = bag_clf.predict(X_test_un)
print('undersampling accuracy:', accuracy_score(y_test_un, y_pred_un))

# %%
bag_clf = BaggingClassifier()

bag_clf.fit(X_train, y_train)

y_pred = bag_clf.predict(X_test)
print('oversampling accuracy:', accuracy_score(y_test_ov, y_pred_ov))

# %% [markdown]
# ## Random Forest

# %%
rnd_clf = RandomForestClassifier(
    n_estimators = 500,  
    max_features = 'auto', 
    max_samples=0.5,    
    bootstrap = True,
    n_jobs=-1
)

rnd_clf.fit(X_train, y_train)

y_pred = rnd_clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9994850368081645

# %%
rnd_clf = RandomForestClassifier()
rnd_clf.fit(X_train, y_train)
y_pred = rnd_clf.predict(X_test)
print('accuracy:', accuracy_score(y_test, y_pred))

# %%
rnd_clf = RandomForestClassifier()
rnd_clf.fit(X_train, y_train)
y_pred = rnd_clf.predict(X_test)
print('undersampling accuracy:', accuracy_score(y_test_un, y_pred_un))

# %%
rnd_clf = RandomForestClassifier()
rnd_clf.fit(X_train, y_train)
y_pred = rnd_clf.predict(X_test)
print('oversampling accuracy:', accuracy_score(y_test_ov, y_pred_ov))

# %% [markdown]
# ## Isolation Forest

# %%
iforest = IsolationForest()#(n_estimators=100, max_samples='auto', 
                         # contamination=0.05, max_features=1.0, 
                         # bootstrap=False, n_jobs=-1, random_state=1)

iforest.fit(X_train, y_train)

y_pred = iforest.predict(X_test)
print('accuracy:', accuracy_score(y_test, y_pred))
# Out:
# 0.00029259272263380267

# %%
iforest = IsolationForest()#(n_estimators=100, max_samples='auto', 
                         # contamination=0.05, max_features=1.0, 
                         # bootstrap=False, n_jobs=-1, random_state=1)

iforest.fit(X_train, y_train)

y_pred = iforest.predict(X_test)
print('undersampling accuracy:', accuracy_score(y_test_un, y_pred_un))

# %%
iforest = IsolationForest()#(n_estimators=100, max_samples='auto', 
                         # contamination=0.05, max_features=1.0, 
                         # bootstrap=False, n_jobs=-1, random_state=1)

iforest.fit(X_train, y_train)

y_pred = iforest.predict(X_test)
print('oversampling accuracy:', accuracy_score(y_test_ov, y_pred_ov))

# %% [markdown]
# ## Extra tree

# %%
et_clf = ExtraTreesClassifier(
    n_estimators = 500, 
    max_leaf_nodes = 16, 
    max_features = 'auto', 
    n_jobs=-1
)

et_clf.fit(X_train, y_train)

y_pred = et_clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9988530365272755

# %%
et_clf = ExtraTreesClassifier()
et_clf.fit(X_train, y_train)
y_pred = et_clf.predict(X_test)
print('accuracy:', accuracy_score(y_test, y_pred))

# %%
et_clf = ExtraTreesClassifier()
et_clf.fit(X_train, y_train)
y_pred = et_clf.predict(X_test)
print('undersampling accuracy:', accuracy_score(y_test_un, y_pred_un))

# %%
et_clf = ExtraTreesClassifier()
et_clf.fit(X_train, y_train)
y_pred = et_clf.predict(X_test)
print('oversampling accuracy:', accuracy_score(y_test_ov, y_pred_ov))

# %% [markdown]
# ## DBSCAN

# %%
dbscan = DBSCAN()
dbscan.fit(X_train, y_train)
y_pred = dbscan.predict(X_test)
print('accuracy:', accuracy_score(y_test, y_pred))

# %%
dbscan = DBSCAN()
dbscan.fit(X_train, y_train)
y_pred = dbscan.predict(X_test)
print('undersampling accuracy:', accuracy_score(y_test_un, y_pred_un))

# %%
dbscan = DBSCAN()
dbscan.fit(X_train, y_train)
y_pred = dbscan.predict(X_test)
print('oversampling accuracy:', accuracy_score(y_test_ov, y_pred_ov))

# %% [markdown]
# # Result
# - AdaBoost: 0.9993562960102056
# - GradientBoosting: 0.9988179254005595
# - XGBoost: 0.9994850368081645
# - lightGBM: 0.996477183619489
# - CATBOOST: 0.9994382219725431
# - Bagging: 0.9982444436641972
# - Random Forest: 0.9994850368081645
# - Extra tree: 0.9988530365272755
